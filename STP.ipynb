# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
dts=pd.read_csv('datasets/HydroWASTE_v10/HydroWASTE_v10.csv',encoding='latin-1')

# %%
dts.head()
# Out:
#    WASTE_ID  SOURCE   ORG_ID                WWTP_NAME    COUNTRY CNTRY_ISO  \
# 0         1       1  1140441     Akmenes aglomeracija  Lithuania       LTU
# 1         2       1  1140443   Alytaus m aglomeracija  Lithuania       LTU
# 2         3       1  1140445    Anyksciu aglomeracija  Lithuania       LTU
# 3         4       1  1140447   Ariogalos aglomeracija  Lithuania       LTU
# 4         5       1  1140449  Baisogalos aglomeracija  Lithuania       LTU
#
#    LAT_WWTP  LON_WWTP  QUAL_LOC  LAT_OUT  ...  QUAL_WASTE      LEVEL  \
# 0    56.247    22.726         2   56.223  ...           4   Advanced
# 1    54.432    24.056         2   54.519  ...           1   Advanced
# 2    55.509    25.073         2   55.452  ...           1   Advanced
# 3    55.252    23.484         2   55.210  ...           1  Secondary
# 4    55.644    23.741         2   55.681  ...           4  Secondary
#
#    QUAL_LEVEL        DF    HYRIV_ID  RIVER_DIS COAST_10KM  COAST_50KM  \
# ...

# %%
dts.columns
# Out:
# Index(['WASTE_ID', 'SOURCE', 'ORG_ID', 'WWTP_NAME', 'COUNTRY', 'CNTRY_ISO',
#        'LAT_WWTP', 'LON_WWTP', 'QUAL_LOC', 'LAT_OUT', 'LON_OUT', 'STATUS',
#        'POP_SERVED', 'QUAL_POP', 'WASTE_DIS', 'QUAL_WASTE', 'LEVEL',
#        'QUAL_LEVEL', 'DF', 'HYRIV_ID', 'RIVER_DIS', 'COAST_10KM', 'COAST_50KM',
#        'DESIGN_CAP', 'QUAL_CAP'],
#       dtype='object')

# %%
dts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58502 entries, 0 to 58501
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WASTE_ID    58502 non-null  int64
#  1   SOURCE      58502 non-null  int64
#  2   ORG_ID      58502 non-null  int64
#  3   WWTP_NAME   53215 non-null  object
#  4   COUNTRY     58502 non-null  object
#  5   CNTRY_ISO   58502 non-null  object
#  6   LAT_WWTP    58502 non-null  float64
#  7   LON_WWTP    58502 non-null  float64
#  8   QUAL_LOC    58502 non-null  int64
#  9   LAT_OUT     58502 non-null  float64
#  10  LON_OUT     58502 non-null  float64
#  11  STATUS      58502 non-null  object
#  12  POP_SERVED  58502 non-null  int64
#  13  QUAL_POP    58502 non-null  int64
#  14  WASTE_DIS   58502 non-null  float64
#  15  QUAL_WASTE  58502 non-null  int64
#  16  LEVEL       58502 non-null  object
#  17  QUAL_LEVEL  58502 non-null  int64
#  18  DF          47302 non-null  float64
# ...

# %%
dtsnew = dts[[ 'WWTP_NAME', 'COUNTRY', 
       'LAT_WWTP', 'LON_WWTP', 'QUAL_LOC','STATUS',
       'POP_SERVED', 'QUAL_POP', 'WASTE_DIS', 'QUAL_WASTE', 'LEVEL',
       'QUAL_LEVEL', 'DF','RIVER_DIS',
       'DESIGN_CAP', 'QUAL_CAP']]

# %%
dtsnew.head()
# Out:
#                  WWTP_NAME    COUNTRY  LAT_WWTP  LON_WWTP  QUAL_LOC  \
# 0     Akmenes aglomeracija  Lithuania    56.247    22.726         2
# 1   Alytaus m aglomeracija  Lithuania    54.432    24.056         2
# 2    Anyksciu aglomeracija  Lithuania    55.509    25.073         2
# 3   Ariogalos aglomeracija  Lithuania    55.252    23.484         2
# 4  Baisogalos aglomeracija  Lithuania    55.644    23.741         2
#
#          STATUS  POP_SERVED  QUAL_POP  WASTE_DIS  QUAL_WASTE      LEVEL  \
# 0  Not Reported        1060         2    148.213           4   Advanced
# 1  Not Reported       87900         2   8797.904           1   Advanced
# 2  Not Reported       12400         2   1959.285           1   Advanced
# 3  Not Reported        2500         2    578.482           1  Secondary
# 4  Not Reported        1200         2    167.788           4  Secondary
#
#    QUAL_LEVEL        DF  RIVER_DIS  DESIGN_CAP  QUAL_CAP
# 0           1  2421.974      4.153      4600.0         2
# ...

# %%
pd.set_option('display.max_rows', None) 
dtsnew['COUNTRY'].value_counts()
# Out:
# COUNTRY
# United States                       14819
# Germany                              4257
# Italy                                4090
# France                               3622
# Brazil                               2820
# Mexico                               2540
# China                                2486
# Spain                                2118
# Canada                               2064
# United Kingdom                       1887
# Poland                               1668
# Russia                               1270
# Australia                            1234
# South Africa                          964
# India                                 816
# Switzerland                           758
# Hungary                               749
# Czech Republic                        663
# Austria                               634
# Romania                               553
# Portugal                              500
# Malaysia                              484
# ...

# %%
dtsnew['STATUS'].value_counts()
# Out:
# STATUS
# Not Reported              53033
# Operational                3767
# Closed                     1164
# Projected                   193
# Under Construction          140
# Proposed                     81
# Non-Operational              76
# Decommissioned               28
# Construction Completed       20
# Name: count, dtype: int64

# %%
dtsnew.head()
# Out:
#                  WWTP_NAME    COUNTRY  LAT_WWTP  LON_WWTP  QUAL_LOC  \
# 0     Akmenes aglomeracija  Lithuania    56.247    22.726         2
# 1   Alytaus m aglomeracija  Lithuania    54.432    24.056         2
# 2    Anyksciu aglomeracija  Lithuania    55.509    25.073         2
# 3   Ariogalos aglomeracija  Lithuania    55.252    23.484         2
# 4  Baisogalos aglomeracija  Lithuania    55.644    23.741         2
#
#          STATUS  POP_SERVED  QUAL_POP  WASTE_DIS  QUAL_WASTE      LEVEL  \
# 0  Not Reported        1060         2    148.213           4   Advanced
# 1  Not Reported       87900         2   8797.904           1   Advanced
# 2  Not Reported       12400         2   1959.285           1   Advanced
# 3  Not Reported        2500         2    578.482           1  Secondary
# 4  Not Reported        1200         2    167.788           4  Secondary
#
#    QUAL_LEVEL        DF  RIVER_DIS  DESIGN_CAP  QUAL_CAP
# 0           1  2421.974      4.153      4600.0         2
# ...

# %%
dtsnew['STATUS'].value_counts()
# Out:
# STATUS
# Not Reported              53033
# Operational                3767
# Closed                     1164
# Projected                   193
# Under Construction          140
# Proposed                     81
# Non-Operational              76
# Decommissioned               28
# Construction Completed       20
# Name: count, dtype: int64

# %%
df_filtered = dtsnew[(dtsnew['STATUS'] == 'Operational') | (dtsnew['STATUS'] == 'Not Reported')]

# %%
df_filtered.head()
# Out:
#                  WWTP_NAME    COUNTRY  LAT_WWTP  LON_WWTP  QUAL_LOC  \
# 0     Akmenes aglomeracija  Lithuania    56.247    22.726         2
# 1   Alytaus m aglomeracija  Lithuania    54.432    24.056         2
# 2    Anyksciu aglomeracija  Lithuania    55.509    25.073         2
# 3   Ariogalos aglomeracija  Lithuania    55.252    23.484         2
# 4  Baisogalos aglomeracija  Lithuania    55.644    23.741         2
#
#          STATUS  POP_SERVED  QUAL_POP  WASTE_DIS  QUAL_WASTE      LEVEL  \
# 0  Not Reported        1060         2    148.213           4   Advanced
# 1  Not Reported       87900         2   8797.904           1   Advanced
# 2  Not Reported       12400         2   1959.285           1   Advanced
# 3  Not Reported        2500         2    578.482           1  Secondary
# 4  Not Reported        1200         2    167.788           4  Secondary
#
#    QUAL_LEVEL        DF  RIVER_DIS  DESIGN_CAP  QUAL_CAP
# 0           1  2421.974      4.153      4600.0         2
# ...

# %%
dtsnew.shape
# Out:
# (58502, 16)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WWTP_NAME   51513 non-null  object
#  1   COUNTRY     56800 non-null  object
#  2   LAT_WWTP    56800 non-null  float64
#  3   LON_WWTP    56800 non-null  float64
#  4   QUAL_LOC    56800 non-null  int64
#  5   STATUS      56800 non-null  object
#  6   POP_SERVED  56800 non-null  int64
#  7   QUAL_POP    56800 non-null  int64
#  8   WASTE_DIS   56800 non-null  float64
#  9   QUAL_WASTE  56800 non-null  int64
#  10  LEVEL       56800 non-null  object
#  11  QUAL_LEVEL  56800 non-null  int64
#  12  DF          46340 non-null  float64
#  13  RIVER_DIS   46500 non-null  float64
#  14  DESIGN_CAP  41043 non-null  float64
#  15  QUAL_CAP    56800 non-null  int64
# dtypes: float64(6), int64(6), object(4)
# memory usage: 7.4+ MB

# %%
df_filtered.drop('WWTP_NAME', axis=1, inplace=True)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_7844\379122816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop('WWTP_NAME', axis=1, inplace=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COUNTRY     56800 non-null  object
#  1   LAT_WWTP    56800 non-null  float64
#  2   LON_WWTP    56800 non-null  float64
#  3   QUAL_LOC    56800 non-null  int64
#  4   STATUS      56800 non-null  object
#  5   POP_SERVED  56800 non-null  int64
#  6   QUAL_POP    56800 non-null  int64
#  7   WASTE_DIS   56800 non-null  float64
#  8   QUAL_WASTE  56800 non-null  int64
#  9   LEVEL       56800 non-null  object
#  10  QUAL_LEVEL  56800 non-null  int64
#  11  DF          46340 non-null  float64
#  12  RIVER_DIS   46500 non-null  float64
#  13  DESIGN_CAP  41043 non-null  float64
#  14  QUAL_CAP    56800 non-null  int64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 6.9+ MB

# %%
df_filtered = df_filtered.drop(['COUNTRY', 'QUAL_LOC','STATUS','QUAL_POP','QUAL_LEVEL','QUAL_WASTE','QUAL_CAP'], axis=1)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_WWTP    56800 non-null  float64
#  1   LON_WWTP    56800 non-null  float64
#  2   POP_SERVED  56800 non-null  int64
#  3   WASTE_DIS   56800 non-null  float64
#  4   LEVEL       56800 non-null  object
#  5   DF          46340 non-null  float64
#  6   RIVER_DIS   46500 non-null  float64
#  7   DESIGN_CAP  41043 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.9+ MB

# %%
df_filtered.duplicated().sum()
# Out:
# np.int64(121)

# %%
df_filtered.columns.tolist()
# Out:
# ['LAT_WWTP',
#  'LON_WWTP',
#  'POP_SERVED',
#  'WASTE_DIS',
#  'LEVEL',
#  'DF',
#  'RIVER_DIS',
#  'DESIGN_CAP']

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_WWTP    56800 non-null  float64
#  1   LON_WWTP    56800 non-null  float64
#  2   POP_SERVED  56800 non-null  int64
#  3   WASTE_DIS   56800 non-null  float64
#  4   LEVEL       56800 non-null  object
#  5   DF          46340 non-null  float64
#  6   RIVER_DIS   46500 non-null  float64
#  7   DESIGN_CAP  41043 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.9+ MB

# %%
df_filtered['DF'].fillna(df_filtered['DF'].median(), inplace=True)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_7844\196045094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filtered['DF'].fillna(df_filtered['DF'].median(), inplace=True)

# %%
df_filtered['RIVER_DIS'].fillna(df_filtered['RIVER_DIS'].median(), inplace=True)
df_filtered['DESIGN_CAP'].fillna(df_filtered['DESIGN_CAP'].median(), inplace=True)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_7844\2115058692.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filtered['RIVER_DIS'].fillna(df_filtered['RIVER_DIS'].median(), inplace=True)
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_7844\2115058692.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_WWTP    56800 non-null  float64
#  1   LON_WWTP    56800 non-null  float64
#  2   POP_SERVED  56800 non-null  int64
#  3   WASTE_DIS   56800 non-null  float64
#  4   LEVEL       56800 non-null  object
#  5   DF          56800 non-null  float64
#  6   RIVER_DIS   56800 non-null  float64
#  7   DESIGN_CAP  56800 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.9+ MB

# %%
columns_to_convert = ['LAT_WWTP','LON_WWTP','WASTE_DIS','DF','RIVER_DIS','DESIGN_CAP']
df_filtered[columns_to_convert] = df_filtered[columns_to_convert].astype(int)

# %%
df_filtered = pd.get_dummies(df_filtered, columns=['LEVEL'], drop_first=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56800 entries, 0 to 58501
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LAT_WWTP         56800 non-null  int64
#  1   LON_WWTP         56800 non-null  int64
#  2   POP_SERVED       56800 non-null  int64
#  3   WASTE_DIS        56800 non-null  int64
#  4   DF               56800 non-null  int64
#  5   RIVER_DIS        56800 non-null  int64
#  6   DESIGN_CAP       56800 non-null  int64
#  7   LEVEL_Primary    56800 non-null  bool
#  8   LEVEL_Secondary  56800 non-null  bool
# dtypes: bool(2), int64(7)
# memory usage: 3.6 MB

# %%
df_filtered.head()
# Out:
#    LAT_WWTP  LON_WWTP  POP_SERVED  WASTE_DIS    DF  RIVER_DIS  DESIGN_CAP  \
# 0        56        22        1060        148  2421          4        4600
# 1        54        24       87900       8797  2534        257      220000
# 2        55        25       12400       1959  1367         30       33000
# 3        55        23        2500        578  2061         13        4357
# 4        55        23        1200        167   209          0        1490
#
#    LEVEL_Primary  LEVEL_Secondary
# 0          False            False
# 1          False            False
# 2          False            False
# 3          False             True
# 4          False             True

# %%
df_filtered.shape
# Out:
# (56800, 9)

# %%
df_filtered.duplicated().sum()
# Out:
# np.int64(406)

# %%
df_filtered = df_filtered.drop_duplicates()

# %%
df_filtered.shape
# Out:
# (56394, 9)

# %%
df_filtered['EFFICIENCY'] = df_filtered['WASTE_DIS'] / df_filtered['DESIGN_CAP']
df_filtered['EFFICIENCY'].fillna(df_filtered['EFFICIENCY'].median(), inplace=True)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_7844\557267805.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filtered['EFFICIENCY'].fillna(df_filtered['EFFICIENCY'].median(), inplace=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56394 entries, 0 to 58501
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LAT_WWTP         56394 non-null  int64
#  1   LON_WWTP         56394 non-null  int64
#  2   POP_SERVED       56394 non-null  int64
#  3   WASTE_DIS        56394 non-null  int64
#  4   DF               56394 non-null  int64
#  5   RIVER_DIS        56394 non-null  int64
#  6   DESIGN_CAP       56394 non-null  int64
#  7   LEVEL_Primary    56394 non-null  bool
#  8   LEVEL_Secondary  56394 non-null  bool
#  9   EFFICIENCY       56394 non-null  float64
# dtypes: bool(2), float64(1), int64(7)
# memory usage: 4.0 MB

# %%
df_filtered.replace([np.inf, -np.inf], np.nan, inplace=True)
df_filtered['EFFICIENCY'] = df_filtered['EFFICIENCY'].fillna(df_filtered['EFFICIENCY'].median())
df_filtered['EFFICIENCY'] = df_filtered['EFFICIENCY'].astype(int)

# %%
x=df_filtered[['LAT_WWTP','LON_WWTP','POP_SERVED','DF','RIVER_DIS','DESIGN_CAP','LEVEL_Primary','LEVEL_Secondary']]
y=df_filtered[['EFFICIENCY']]

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor  
model = RandomForestRegressor(n_estimators=100, random_state=42)  
model.fit(X_train, y_train)
# Out:
# C:\Users\saurabh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score  
y_pred = model.predict(X_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.40222091413034755
# MSE: 10.72973260661783
# R² Score: 0.7427280623116483
